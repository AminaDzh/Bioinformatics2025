# %% [markdown]
# ## Домашнее задание 7
#
# 1. Филогенетическое дерево для последовательностей S-белков
#
# Возьмем 3 последовательности для разных штаммов и добавим к ним первую последовательность с семинара >10825.
#
# Wuhan-Hu-1 : MN908947.3
#
# Delta : OK091006.1
#
# Omicron BA.1 : OL672836.1
#
# Далее выровняем с помощью ClustalW, а в MEGA построим дерево
#
# ![image.png](attachment:8c1fd4ad-4ef2-4eee-b69b-f587fd83af96.png)
#
# Штамм, рассмотреный на семинаре, достаточно близок к Omicron. А оригинальныый штамм ближе к Delta, причем разделились они позднее. Я себе по другому представляла результат, думала что от оригинального штамма по очерерди будут ответвляться другие, временные масштабы я ожидала тоже другие

# %% [markdown]
# 2. Филогенетическое дерево для ортологов F9 - девятый фактор коагуляции крови
#
# https://www.ncbi.nlm.nih.gov/gene/2158/ortholog/?scope=7776&term=F9
#
# ![image.png](attachment:e34a072f-9523-4eeb-8837-31e3b524fe32.png)

# %% [markdown]
# Возьмем последовательности мыши, крысы, собаки, свиньи, макаки-резус,шимпнзе, кота и овцы. В качестве внешней группы у нас будет курица. Построим выравнивание ClustalW, а филогенетическое дерево в MEGA

# %% [markdown]
# ![image.png](attachment:05901340-a0bd-44a7-a719-45164ade2e06.png)

# %% [markdown]
# Результат мне снова не нравится. Мышь и крыса в одной кладе - это хорошо. Но например собаку объединили с внешней группой - курицей. Из хорошего курица действительно внешняя группа. Макаку и шимпанзе поставили в разные клады. Овца оказалась с макакой, а кошка с шимпанзе. Из этого можно сделать вывод, что девятый фактор свертывания плохо подходит для построения филогенетического дерева. Это скорее всего связано с большой скоростью накопления мутаций.
